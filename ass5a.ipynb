# %%
import numpy as np;

# %%
a=np.array([1,2,6,7])

# %%
print(a+2)
# Out:
# [3 4 8 9]

# %%
print(a*3)
# Out:
# [ 3  6 18 21]

# %%
print(a/2)
# Out:
# [0.5 1.  3.  3.5]

# %%
a=[1,2,3,4,5,6,7,8]

# %%
reverse_arr=a[::-1]

# %%
print(reverse_arr)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
x=np.array([1,2,3,4,5,1,2,1,1,1])

# %%
values,count=np.unique(x,return_counts=True)

# %%
most_frequent=values[np.argmax(count)]

# %%
indices=np.where(x==most_frequent)[0]

# %%
print("Most frquent value is",most_frequent,"in index:")
# Out:
# Most frquent value is 1 in index:

# %%
print(indices)
# Out:
# [0 5 7 8 9]

# %%
arr=np.array([[10,20,30],[40,50,60],[70,80,90]])

# %%
print(arr[0])
# Out:
# [10 20 30]

# %%
for i in range(0,3):
  print(arr[i][1])
# Out:
# 20
# 50
# 80

# %%
print(arr[2])
# Out:
# [70 80 90]

# %%
for i in range(0,3):
  print(arr[i][0])
# Out:
# 10
# 40
# 70

# %%
Shounok=np.linspace(10,100,25)

# %%
print(Shounok)
# Out:
# [ 10.    13.75  17.5   21.25  25.    28.75  32.5   36.25  40.    43.75
#   47.5   51.25  55.    58.75  62.5   66.25  70.    73.75  77.5   81.25
#   85.    88.75  92.5   96.25 100.  ]

# %%
print(Shounok.ndim)
# Out:
# 1

# %%
print(Shounok.shape)
# Out:
# (25,)

# %%
print(Shounok.size)
# Out:
# 25

# %%
print(Shounok.dtype)
# Out:
# float64

# %%
print(Shounok.nbytes)
# Out:
# 200

# %%
print(Shounok.reshape(25,1))
# Out:
# [[ 10.  ]
#  [ 13.75]
#  [ 17.5 ]
#  [ 21.25]
#  [ 25.  ]
#  [ 28.75]
#  [ 32.5 ]
#  [ 36.25]
#  [ 40.  ]
#  [ 43.75]
#  [ 47.5 ]
#  [ 51.25]
#  [ 55.  ]
#  [ 58.75]
#  [ 62.5 ]
#  [ 66.25]
#  [ 70.  ]
#  [ 73.75]
#  [ 77.5 ]
#  [ 81.25]
#  [ 85.  ]
#  [ 88.75]
#  [ 92.5 ]
#  [ 96.25]
#  [100.  ]]

# %%
UCS420_Shounok=np.array([[10,20,30,40],[50,60,70,80],[90,15,20,35]])

# %%
Mean=np.mean(UCS420_Shounok)

# %%
print(Mean)
# Out:
# 43.333333333333336

# %%
Median=np.median(UCS420_Shounok)

# %%
print(Median)
# Out:
# 37.5

# %%
print("Maximum:", np.max(ucs420_yourname))
print("Minimum:", np.min(ucs420_yourname))
print("Unique Elements:", np.unique(ucs420_yourname))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3964/588625791.py in <cell line: 0>()
# ----> 1 print("Maximum:", np.max(ucs420_yourname))
#       2 print("Minimum:", np.min(ucs420_yourname))
#       3 print("Unique Elements:", np.unique(ucs420_yourname))
#
# NameError: name 'ucs420_yourname' is not defined

# %%
reshaped_ucs420_yourname = ucs420_yourname.reshape(4, 3)

print("\nReshaped Array (4 x 3):")
print(reshaped_ucs420_yourname)

# Resize to 2 rows and 3 columns
resized_ucs420_yourname = np.resize(ucs420_yourname, (2, 3))

print("\nResized Array (2 x 3):")
print(resized_ucs420_yourname)
